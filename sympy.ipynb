# %%
# Import the required modules for the following codes

import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import pandas as pd
import sympy as sy
sy.init_session(use_latex=True)
sy.init_printing(use_latex=True)
sns.set(style="white",color_codes=True)
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15,9.27)
plt.rcParams['font.size'] = 10.0
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
# Out:
# IPython console for SymPy 1.0 (Python 3.6.1-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at http://docs.sympy.org/1.0/

# %%
x = np.arange(-5,5,0.01)
y = np.arange(-5,5,0.01)
X, Y = np.meshgrid(x, y)
Z = X**2+Y**2

cmap = plt.cm.get_cmap("Dark2")
CS = plt.contour(X, Y, Z,cmap=cmap)
plt.clabel(CS,inline=1, fontsize=10,fmt='%2.0f')
plt.scatter(0,0)

# %%
def latex(x):
    if x == '':
        return ''
    elif isinstance(x,str) == False:
        return r'$'+str(x)+'$'
    else:
        words = x.split()
        s = ' \ '
        b = s.join(words)
        res = r'$' + b + '$'
        return res

# %%
def fplot(func,beg,end,lw=2,xlab='x',ylab='y',title='',fs=20):
    x = np.arange(beg,end+0.001,0.001)
    y = np.array(list(map(func,x)))
    plt.plot(x,y,linewidth=lw)
    plt.xlim(beg,end)
    plt.xlabel(latex(xlab),fontsize=fs)
    plt.ylabel(latex(ylab),fontsize=fs)
    plt.title(latex(title),fontsize=fs)

# %%
f = lambda x : x*exp(-x)
fplot(f,0,5,title='the relationship between x and y')

# %%
x, y, a = sy.symbols('x y a')

# %%
x
# Out:
# x

# %%
expr = (x-y)**2

# %%
expr
# Out:
#        2
# (x - y)

# %%
expr.expand()
# Out:
#  2            2
# x  - 2⋅x⋅y + y

# %%
res = (expr**5).expand()

# %%
diff(res,x)
# Out:
#     9       8          7  2        6  3         5  4         4  5        3  6
# 10⋅x  - 90⋅x ⋅y + 360⋅x ⋅y  - 840⋅x ⋅y  + 1260⋅x ⋅y  - 1260⋅x ⋅y  + 840⋅x ⋅y
#
#        2  7         8       9
# - 360⋅x ⋅y  + 90⋅x⋅y  - 10⋅y

# %%
integrate(exp(x)*sin(x) + exp(x)*cos(x), x)
# Out:
#  x
# ℯ ⋅sin(x)

# %%
import math

# %%
f2 = sy.sqrt(a**2+x**2)

# %%
# %timeit integrate(f2,x)
# Out:
# 1 loop, best of 3: 1.75 s per loop

# %%
f3 = 1/sy.sqrt(x**2-a**2)

# %%
integrate(f3,x)
# Out:
# ⎧                │ 2│
# ⎪      ⎛x⎞       │x │
# ⎪ acosh⎜─⎟   for │──│ > 1
# ⎪      ⎝a⎠       │ 2│
# ⎨                │a │
# ⎪
# ⎪       ⎛x⎞
# ⎪-ⅈ⋅asin⎜─⎟   otherwise
# ⎩       ⎝a⎠

# %%
integrate(x**n,x)
# Out:
# ⎧log(x)  for n = -1
# ⎪
# ⎪ n + 1
# ⎨x
# ⎪──────  otherwise
# ⎪n + 1
# ⎩

# %%
# Import the required modules for the following codes

import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import pandas as pd
sns.set(style="white",context="poster",color_codes=True)
# %matplotlib inline

x = np.random.randn(100)
y = np.random.randn(100)
sns.regplot(x,y)
plt.xlabel(r'$x$')
plt.ylabel(r'$y^2+e^x$')
# Out:
# Text(0,0.5,'$y^2+e^x$')

# %%
integrate(1/(1+x**2),x)
# Out:
# atan(x)

# %%
f4 = 1/(1+x**2)

# %%
g = sy.lambdify(x,f4)

# %%
fplot(g,-5,5)

# %%
h = (x+1)**5

# %%
h.expand()
# Out:
#  5      4       3       2
# x  + 5⋅x  + 10⋅x  + 10⋅x  + 5⋅x + 1

# %%
h1 = integrate(h,x)

# %%
h1.factor()
# Out:
#           ⎛ 2        ⎞ ⎛ 2          ⎞
# x⋅(x + 2)⋅⎝x  + x + 1⎠⋅⎝x  + 3⋅x + 3⎠
# ─────────────────────────────────────
#                   6

# %%
h2 = integrate(h1,x)

# %%
h2.factor()
# Out:
#  2 ⎛ 5      4       3       2            ⎞
# x ⋅⎝x  + 7⋅x  + 21⋅x  + 35⋅x  + 35⋅x + 21⎠
# ──────────────────────────────────────────
#                     42

# %%
integrate(sin(x),(x,0,pi))
# Out:
# 2

# %%
integrate(x**2,(x,0,1))
# Out:
# 1/3

# %%
integrate(x**2,(x,0,a))
# Out:
#  3
# a
# ──
# 3

# %%
summation(x**2,(x,1,n))
# Out:
#  3    2
# n    n    n
# ── + ── + ─
# 3    2    6

# %%
_.factor()
# Out:
# n⋅(n + 1)⋅(2⋅n + 1)
# ───────────────────
#          6

# %%
(summation(x**4,(x,1,n))).factor()
# Out:
#                     ⎛   2          ⎞
# n⋅(n + 1)⋅(2⋅n + 1)⋅⎝3⋅n  + 3⋅n - 1⎠
# ────────────────────────────────────
#                  30
